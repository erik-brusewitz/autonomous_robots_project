# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="vMvKMIy9EBzByJMywMqj")
project = rf.workspace("kiwidetection-kdou2").project("kiwi-detection-rgb-images")
dataset = project.version(1).download("darknet")

# %%
# %%bash
# mkdir darknet_dataset backup
# mkdir darknet_dataset/images
# cp kiwi-detection-rgb-images-1/train/* darknet_dataset/images
# cp kiwi-detection-rgb-images-1/valid/* darknet_dataset/images
# ls kiwi-detection-rgb-images-1/train/*.jpg > darknet_dataset/train.txt
# sed 's/^/darknet_dataset\/train\//' darknet_dataset/train.txt
# ls kiwi-detection-rgb-images-1/valid/*.jpg > darknet_dataset/test.txt
# sed 's/^/darknet_dataset\/test\//' darknet_dataset/test.txt
# echo "kiwi_cart" > darknet_dataset/labels.names
# echo $'classes=1\ntrain=darknet_dataset/train.txt\nvalid=darknet_dataset/test.txt\nnames=darknet_dataset/labels.names\nbackup=backup/' > detector.data
# # rm -r /content/kiwi-detection-rgb-images-1
# Out:
# darknet_dataset/train/kiwi-detection-rgb-images-1/train/1534849290367911_png.rf.31e911b49ceb1c638aece4630425b881.jpg
# darknet_dataset/train/kiwi-detection-rgb-images-1/train/1534849290367911_png.rf.4dd94f1b21cd33363ac395e674d57326.jpg
# darknet_dataset/train/kiwi-detection-rgb-images-1/train/1534849290367911_png.rf.f57f13a2ed4451c5660a32252a139442.jpg
# darknet_dataset/train/kiwi-detection-rgb-images-1/train/1534849291070018_png.rf.01406868bf6708ebbdf18b3ee8c13ce4.jpg
# darknet_dataset/train/kiwi-detection-rgb-images-1/train/1534849291070018_png.rf.0750169515daa6c91bb23def4afa3d76.jpg
# darknet_dataset/train/kiwi-detection-rgb-images-1/train/1534849291070018_png.rf.8f00ec7c0c482117dc03456c522c665d.jpg
# darknet_dataset/train/kiwi-detection-rgb-images-1/train/1534849291168990_png.rf.5111f565316de755d649128ea0a85d86.jpg
# darknet_dataset/train/kiwi-detection-rgb-images-1/train/1534849291168990_png.rf.557bfe0f72b3a8cdc07713512dc08d00.jpg
# ...

# %%
# %%bash
# git clone https://github.com/dog-qiuqiu/Yolo-Fastest.git
# cd Yolo-Fastest/
# make
# ./darknet partial ./ModelZoo/yolo-fastest-1.1_coco/yolo-fastest-1.1.cfg ./ModelZoo/yolo-fastest-1.1_coco/yolo-fastest-1.1.weights yolo-fastest.conv.109 109
# mkdir inititial_weights
# cp ./ModelZoo/yolo-fastest-1.1_coco/yolo-fastest-1.1.weights ./inititial_weights
# cp ./ModelZoo/yolo-fastest-1.1_coco/yolo-fastest-1.1.cfg ./inititial_weights
# cp ./yolo-fastest.conv.109 ./inititial_weights
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -ffp-contract=fast -mavx -mavx2 -msse3 -msse4.1 -msse4.2 -msse4a -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -ffp-contract=fast -mavx -mavx2 -msse3 -msse4.1 -msse4.2 -msse4a -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/http_stream.cpp -o obj/http_stream.o
# ...

# %%
# !./Yolo-Fastest/darknet detector train detector.data ./Yolo-Fastest/inititial_weights/yolo-fastest-1.1.cfg ./Yolo-Fastest/inititial_weights/yolo-fastest.conv.109 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 130 Avg (IOU: 0.886744), count: 61, class_loss = 0.000001, iou_loss = 1.985308, total_loss = 1.985309
#  total_bbox = 2700830, rewritten_bbox = 0.000000 %
#
#  25418: 0.000260, 0.000279 avg loss, 0.001000 rate, 0.240502 seconds, 813376 images, 31.136860 hours left
# Loaded: 0.000050 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 121 Avg (IOU: 0.880756), count: 48, class_loss = 0.000003, iou_loss = 0.730048, total_loss = 0.730051
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 130 Avg (IOU: 0.903101), count: 57, class_loss = 0.000001, iou_loss = 2.118712, total_loss = 2.118713
#  total_bbox = 2700935, rewritten_bbox = 0.000000 %
#
#  25419: 0.000238, 0.000275 avg loss, 0.001000 rate, 0.239829 seconds, 813408 images, 31.142667 hours left
# Loaded: 0.000075 seconds
# ...
